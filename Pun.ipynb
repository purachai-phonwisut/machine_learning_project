# %%
import pandas as pd
# Out:
# C:\Users\3lett\AppData\Local\Temp\ipykernel_1200\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('./Data cleaned/Disposable_income_adj.csv')
df
# Out:
#             Geography           Category                  Data Type  \
# 0          Azerbaijan  Disposable Income  Socio-economic indicators
# 1          Bangladesh  Disposable Income  Socio-economic indicators
# 2            Cambodia  Disposable Income  Socio-economic indicators
# 3               China  Disposable Income  Socio-economic indicators
# 4    Hong Kong, China  Disposable Income  Socio-economic indicators
# ..                ...                ...                        ...
# 98              Spain  Disposable Income  Socio-economic indicators
# 99             Sweden  Disposable Income  Socio-economic indicators
# 100       Switzerland  Disposable Income  Socio-economic indicators
# 101            Turkey  Disposable Income  Socio-economic indicators
# 102    United Kingdom  Disposable Income  Socio-economic indicators
#
#             Unit  Currency Conversion Current Constant         2011  \
# 0    USD million  Fixed 2023 ex rates   Current Prices     12,100.4
# ...
