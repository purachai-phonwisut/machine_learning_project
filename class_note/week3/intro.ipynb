# %%
import pandas as pd

# %%
df = pd.read_csv("movie_gross.csv")
df

# %%
df.info()

# %%
dx=pd.read_excel('disney.xlsx', sheet_name="gross")
dx
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
dg = pd.read_excel("Luxury Leather Goods.xlsx")
dg
# Out:
#                                             Geography              Category  \
# 0                                               China  Luxury Leather Goods
# 1                                               China  Luxury Leather Goods
# 2                                    Hong Kong, China  Luxury Leather Goods
# 3                                    Hong Kong, China  Luxury Leather Goods
# 4                                               India  Luxury Leather Goods
# ..                                                ...                   ...
# 65                                  Research Sources:                   NaN
# 66  Luxury Goods: Euromonitor from trade sources/n...                   NaN
# 67                                                NaN                   NaN
# 68          Date Exported (GMT): 1/23/2024 2:46:47 PM                   NaN
# 69                        © Euromonitor International                   NaN
#
# ...

# %%
dv = dg[dg["Data Type"] == "Retail Volume"]

# %%
dv.to_csv('lux retail vol.csv')
